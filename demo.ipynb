# %% [markdown]
# <a href="https://colab.research.google.com/github/Amr789/face-editor/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repository
# !git clone https://github.com/Amr789/face-editor.git

# Enter the directory
# %cd face-editor
# Out:
# Cloning into 'face-editor'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 29 (delta 7), reused 19 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 44.07 MiB | 16.07 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/face-editor/face-editor

# %%
# 1. Install Python libraries
# !pip install -r requirements.txt

# 2. Run your setup script (Downloads e4e weights, boundaries, and dlib)
# !python setup.py
# Out:
# ...
# Cloning encoder4editing...
# Cloning into 'encoder4editing'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 172 (delta 50), reused 44 (delta 44), pack-reused 93 (from 1)
# Receiving objects: 100% (172/172), 32.98 MiB | 16.04 MiB/s, done.
# Resolving deltas: 100% (59/59), done.
# ⬇️ Downloading pretrained_models/e4e_ffhq_encode.pt...
# ⬇️ Downloading editing_directions/age_boundary.npy...
# ⬇️ Downloading editing_directions/smile_boundary.npy...
# ⬇️ Downloading editing_directions/pose_boundary.npy...
# ⬇️ Downloading editing_directions/gender_boundary.npy...
# ...
# ⬇️ Downloading shape_predictor.dat.bz2...
# Extracting Dlib...
#
# ✅ Setup Complete! You can now run main.py

# %%
from google.colab import files
import os

# Upload file
print("Please upload a face image (jpg/png)...")
uploaded = files.upload()
filename = list(uploaded.keys())[0]

print(f"✅ Ready to process: {filename}")
# Out:
# Please upload a face image (jpg/png)...
#      <input type="file" id="files-94be37ac-01a4-4599-b6ab-aa558954ee7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94be37ac-01a4-4599-b6ab-aa558954ee7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
from IPython.display import Image, display

# Run the pipeline (Using the filename from the previous cell)
# !python main.py --image "{filename}"

# Display the output
print("\n👇 Here is your result:")
display(Image('result.png'))
# Out:
# Loading model from pretrained_models/e4e_ffhq_encode.pt...
# Loading e4e over the pSp framework from checkpoint: pretrained_models/e4e_ffhq_encode.pt
# Processing test (1).jpg...
# ✅ Done! Results saved to result.png
#
# 👇 Here is your result:
